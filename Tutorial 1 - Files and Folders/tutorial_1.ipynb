# %% [markdown]
# # Tutorial 1: Working with Files in Python
#
# This tutorial can be found in this link [Working with Files in Python](https://realpython.com/working-with-files-in-python/).
#
# **Note:** Use Markdown headings to create sections in the notebook. Run each snippet of code in one cell.

# %% [markdown]
# By Li Yin

# %% [markdown]
# ## 1. `with ... open as` pattern

# %%
import os

# %%
with open('data.txt', 'r') as f:
    data = f.read()

# %%
with open('data.txt', 'w') as f:
    data = 'some data to be written to the file'
    f.write(data)

# %% [markdown]
# ## 2. Listing All Files in a Directory

# %%
basepath = '/Users/likeirayin/Desktop/School/CS315/cs315-week1-tasks/Tutorial 1 - Files and Folders'
for entry in os.listdir(basepath):
    if os.path.isfile(os.path.join(basepath, entry)):
        print(entry)
# Out:
# tutorial_1.ipynb
# data.txt

# %%
from pathlib import Path
basepath = Path('/Users/likeirayin/Desktop/School/CS315/cs315-week1-tasks/Tutorial 1 - Files and Folders')
for entry in basepath.iterdir():
    if entry.is_dir():
        print(entry.name)

# %% [markdown]
# ## 3. Getting file attributes

# %%
from datetime import datetime
from os import scandir

def convert_date(timestamp):
    d = datetime.utcfromtimestamp(timestamp)
    formated_date = d.strftime('%d %b %Y')
    return formated_date

def get_files():
    dir_entries = scandir('/Users/likeirayin/Desktop/School/CS315/cs315-week1-tasks/Tutorial 1 - Files and Folders')
    for entry in dir_entries:
        if entry.is_file():
            info = entry.stat()
            print(f'{entry.name}\t Last Modified: {convert_date(info.st_mtime)}')

# %% [markdown]
# ## 3. Making Directories

# %%
import os

os.mkdir('example_directory/')

# %%
from pathlib import Path

p = Path('example_directory')
try:
    p.mkdir()
except FileExistsError as exc:
    print(exc)
# Out:
# [Errno 17] File exists: 'example_directory'

# %%
os.makedirs('2026/09/05', mode=0o770)

# %%
import glob
for file in glob.iglob('**/*.py', recursive=True):
    print(file)

# %%
import glob
glob.glob('*.py')
# Out:
# []

# %%
import glob
for name in glob.glob('*[0-9]*.txt'):
    print(name)

# %%
from pathlib import Path
p = Path('.')
for name in p.glob('*.p*'):
    print(name)

# %% [markdown]
# ## 4. Traversing Directories and Processing Files

# %%
# Walking a directory tree and printing the names of the directories and files
for dirpath, dirnames, files in os.walk('.'):
    print(f'Found directory: {dirpath}')
    for file_name in files:
        print(file_name)
# Out:
# Found directory: .
# tutorial_1.ipynb
# data.txt
# Found directory: ./2026
# Found directory: ./2026/09
# Found directory: ./2026/09/04
# Found directory: ./2026/09/05
# Found directory: ./example_directory

# %%
for dirpath, dirnames, files in os.walk('.', topdown=False):
    print(f'Found directory: {dirpath}')
    for file_name in files:
        print(file_name)
# Out:
# Found directory: ./2026/09/04
# Found directory: ./2026/09/05
# Found directory: ./2026/09
# Found directory: ./2026
# Found directory: ./example_directory
# Found directory: .
# tutorial_1.ipynb
# data.txt

# %% [markdown]
# ## 5. Making Temporary Files and Directories

# %%
from tempfile import TemporaryFile

fp = TemporaryFile('w+t')
fp.write('Hello universe!')

fp.seek(0)
data = fp.read()

fp.close()

# %%
with TemporaryFile('w+t') as fp:
    fp.write('Hello universe!')
    fp.seek(0)
    fp.read()

# %% [markdown]
# ## 6. Deleting Files

# %%
import os

data_file = '/Users/likeirayin/Desktop/School/CS315/cs315-week1-tasks/Tutorial 1 - Files and Folders/data copy.txt'
os.remove(data_file)

# %%
data_file = 'home/data.txt'

if os.path.isfile(data_file):
    os.remove(data_file)
else:
    print(f'Error: {data_file} not a valid filename')
# Out:
# Error: home/data.txt not a valid filename

# %% [markdown]
# ## 7. Deleting Directories

# %%
trash_dir = 'my_documents/bad_dir'

try:
    os.rmdir(trash_dir)
except OSError as e:
    print(f'Error: {trash_dir} : {e.strerror}')
# Out:
# Error: my_documents/bad_dir : No such file or directory

# %%
from pathlib import Path

trash_dir = Path('my_documents/bad_dir')

try:
    trash_dir.rmdir()
except OSError as e:
    print(f'Error: {trash_dir} : {e.strerror}')
# Out:
# Error: my_documents/bad_dir : No such file or directory

# %%
import shutil

trash_dir = 'my_documents/bad_dir'

try:
    shutil.rmtree(trash_dir)
except OSError as e:
    print(f'Error: {trash_dir} : {e.strerror}')
# Out:
# Error: my_documents/bad_dir : No such file or directory

# %%
import os

for dirpath, dirnames, files in os.walk('.', topdown=False):
    try:
        os.rmdir(dirpath)
    except OSError as ex:
        pass

# %% [markdown]
# ## 8. Copying, Moving, and Renaming Files and Directories

# %%
import shutil

src = '/Users/likeirayin/Desktop/School/CS315/cs315-week1-tasks/Tutorial 1 - Files and Folders/data.txt'
dst = '/Users/likeirayin/Desktop/School/CS315/cs315-week1-tasks'
shutil.copy(src, dst)
# Out:
# '/Users/likeirayin/Desktop/School/CS315/cs315-week1-tasks/data.txt'

# %%
os.rename('/Users/likeirayin/Desktop/School/CS315/cs315-week1-tasks/Tutorial 1 - Files and Folders/data.txt', '/Users/likeirayin/Desktop/School/CS315/cs315-week1-tasks/Tutorial 1 - Files and Folders/data2.txt')

# %% [markdown]
# ## 9. Archiving

# %%
import zipfile

with zipfile.ZipFile('data.zip', 'r') as zipobj:
    zipobj.namelist()

# %%
import tarfile

with tarfile.open('example.tar', 'r') as tar_file:
    print(tar_file.getnames())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[59], line 3
#       1 import tarfile
# ----> 3 with tarfile.open('example.tar', 'r') as tar_file:
#       4     print(tar_file.getnames())
#
# File /opt/anaconda3/lib/python3.12/tarfile.py:1802, in TarFile.open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1800     saved_pos = fileobj.tell()
#    1801 try:
# -> 1802     return func(name, "r", fileobj, **kwargs)
#    1803 except (ReadError, CompressionError) as e:
#    1804     error_msgs.append(f'- method {comptype}: {e!r}')
#
# File /opt/anaconda3/lib/python3.12/tarfile.py:1870, in TarFile.gzopen(cls, name, mode, fileobj, compresslevel, **kwargs)
#    1867     raise CompressionError("gzip module is not available") from None
#    1869 try:
# -> 1870     fileobj = GzipFile(name, mode + "b", compresslevel, fileobj)
#    1871 except OSError as e:
# ...
